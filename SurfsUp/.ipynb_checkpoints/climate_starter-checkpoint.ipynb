# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# create engine to hawaii.sqlite
engine = create_engine("sqlite:///../Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine = engine, reflect = True)

# %%
# View all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Precipt = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# exploring data structure
session.query(Precipt).first().__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x16a97be5d88>,
#  'date': '2010-01-01',
#  'tobs': 65.0,
#  'id': 1,
#  'station': 'USC00519397',
#  'prcp': 0.08}

# %%
# Find the most recent date in the data set.
recent_date_q = session.query(Precipt.date).order_by(Precipt.date.desc()).first()
print(f"The most recent date is: {recent_date_q[0]}")
# Out:
# The most recent date is: 2017-08-23

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
# ----------------------------------------------------------------------------------------
# Starting from the most recent data point in the database. 
recent_date = dt.datetime.strptime(recent_date_q[0], '%Y-%m-%d').date()

# Calculate the date one year from the last date in data set.
year_from_recent_date = recent_date - dt.timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
prcp_data = session.query(Precipt.date, Precipt.prcp).\
    filter(Precipt.date <= recent_date).\
    filter(Precipt.date >= year_from_recent_date).all()
prcp_data
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
prcp_df = pd.DataFrame(prcp_data, columns=['date', 'precipitation'])
prcp_df.set_index('date', inplace=True)

# Sort the dataframe by date
prcp_df = prcp_df.sort_values("date", ascending=True)
prcp_df.head(10)
# Out:
#             precipitation
# date
# 2016-08-23           0.00
# 2016-08-23            NaN
# 2016-08-23           1.79
# 2016-08-23           0.05
# 2016-08-23           0.15
# 2016-08-23           0.70
# 2016-08-23           0.02
# 2016-08-24           0.08
# 2016-08-24           2.15
# 2016-08-24           2.28

# %%
# Use Pandas Plotting with Matplotlib to plot the data
prcp_df.plot.line(figsize=(15, 7))
plt.xlabel("Date")   
plt.ylabel("Precipitation in Inches")
plt.title("Precipitation by Date: Aug 2016 to Aug 2017")
plt.xticks(rotation='vertical', fontsize=10)
plt.tight_layout()
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcp_df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# exploring data structure
session.query(Station).first().__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x16a98701548>,
#  'id': 1,
#  'name': 'WAIKIKI 717.2, HI US',
#  'longitude': -157.8168,
#  'station': 'USC00519397',
#  'latitude': 21.2716,
#  'elevation': 3.0}

# %%
# Design a query to calculate the total number stations in the dataset
num_stations = session.query(func.count(Station.station)).all()
print(f"There are {num_stations[0][0]} total station in the dataset")
# Out:
# There are 9 total station in the dataset

# %%
# Design a query to find the most active stations (i.e. what stations have the most rows?)
# List the stations and the counts in descending order.
results = session.query(Precipt.station, func.count().label('count')).\
            group_by(Precipt.station).\
            order_by(func.count().desc()).all()

for row in results:
    print(f"Station code: {row.station}, Number of records for this station: {row.count}")
print("-" * 70)
print(f"Station {results[0].station} is the most active")
# Out:
# Station code: USC00519281, Number of records for this station: 2772
# Station code: USC00519397, Number of records for this station: 2724
# Station code: USC00513117, Number of records for this station: 2709
# Station code: USC00519523, Number of records for this station: 2669
# Station code: USC00516128, Number of records for this station: 2612
# Station code: USC00514830, Number of records for this station: 2202
# Station code: USC00511918, Number of records for this station: 1979
# Station code: USC00517948, Number of records for this station: 1372
# Station code: USC00518838, Number of records for this station: 511
# ----------------------------------------------------------------------
# Station USC00519281 is the most active

# %%
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
active_sum = session.query(Precipt.station, func.min(Precipt.prcp), func.max(Precipt.prcp), func.avg(Precipt.prcp)).\
    filter(Precipt.station == "USC00519281").all()
print(active_sum)
print("-" * 70)
print(f"Summary Statistics for station {active_sum[0][0]}")
print("-" * 70)
print(f"Minimum precipitation: {active_sum[0][1]}")
print(f"Maximum precipitation: {active_sum[0][2]}")
print(f"Average precipitation: {round(active_sum[0][3], 2)}")
# Out:
# [('USC00519281', 0.0, 9.64, 0.2123520923520915)]
# ----------------------------------------------------------------------
# Summary Statistics for station USC00519281
# ----------------------------------------------------------------------
# Minimum precipitation: 0.0
# Maximum precipitation: 9.64
# Average precipitation: 0.21

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
active_temp = session.query(Precipt.station, Precipt.tobs).\
    filter(Precipt.station == "USC00519281").\
    filter(Precipt.date <= recent_date).\
    filter(Precipt.date >= year_from_recent_date).all()
active_temp
# Out:
# [('USC00519281', 77.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
# ...

# %%
# convert to data frame
temp_df = pd.DataFrame(active_temp, columns=['station', 'temperature'])
temp_df.set_index('station', inplace=True)
temp_df.head()
# Out:
#              temperature
# station
# USC00519281         77.0
# USC00519281         77.0
# USC00519281         80.0
# USC00519281         80.0
# USC00519281         75.0

# %%
# create histogram
plt.hist(temp_df["temperature"], bins=12, label='tobs')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Temperature Histogram')
plt.legend()
plt.show()

# %% [markdown]
# # Close session

# %%
# Close Session
session.close()
